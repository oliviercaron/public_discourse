# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import dateparser
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.7-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#    ---------------------------------------- 0.0/235.5 kB ? eta -:--:--
#    -------------------------------------- - 225.3/235.5 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 235.5/235.5 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.7

# %%
# Configuration du pilote Chrome
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# Accéder à la page
driver.get("https://www.vie-publique.fr/discours?page=0")

# Trouver tous les éléments de la classe 'fr-card__content'
cards = driver.find_elements(By.CLASS_NAME, "fr-card__content")

# Liste pour stocker les données
data = []

for card in cards:
    # Extraire les informations de chaque carte
    nature = card.find_element(By.CSS_SELECTOR, ".fr-card__start .field__item").text
    titre = card.find_element(By.CSS_SELECTOR, ".fr-card__title a").text
    lien = card.find_element(By.CSS_SELECTOR, ".fr-card__title a").get_attribute("href")
    date_text = card.find_element(By.CSS_SELECTOR, ".fr-card__end time").text
    # Convertir la date en format standard (yyyy-mm-dd)
    date = dateparser.parse(date_text).date().isoformat()

    data.append({"nature": nature, "titre": titre, "lien": lien, "date": date})

# Créer un DataFrame
df = pd.DataFrame(data)

# Afficher le DataFrame
print(df)

# Fermer le navigateur
driver.quit()
df
# Out:
#          nature                                              titre  \
# 0    Communiqué  Conseil des ministres du 12 décembre 2023. Acc...
# 1     Interview  Interview de M. Gérald Darmanin, ministre de l...
# 2   Déclaration  Déclaration de Mme Catherine Colonna, ministre...
# 3    Communiqué  Communiqué de presse du ministère de l'Europe ...
# 4    Communiqué  Conseil des ministres du 12 décembre 2023. Ter...
# 5    Communiqué  Conseil des ministres du 12 décembre 2023. Int...
# 6    Communiqué  Conseil des ministres du 12 décembre 2023. Rém...
# 7   Déclaration  Déclaration de Mme Laurence Boone, secrétaire ...
# 8    Communiqué  Conseil des ministres du 12 décembre 2023. Mes...
# 9     Interview  Interview de M. Gérald Darmanin, ministre de l...
# 10  Déclaration  Déclaration à la presse de Mme Catherine Colon...
# 11  Déclaration  Déclaration de M. Marc Fesneau, ministre de l'...
#
#                                                  lien        date
# 0   https://www.vie-publique.fr/discours/292384-co...  2023-12-12
# 1   https://www.vie-publique.fr/discours/292393-ge...  2023-12-12
# 2   https://www.vie-publique.fr/discours/292402-ca...  2023-12-12
# 3   https://www.vie-publique.fr/discours/292399-mi...  2023-12-12
# 4   https://www.vie-publique.fr/discours/292386-co...  2023-12-12
# 5   https://www.vie-publique.fr/discours/292383-co...  2023-12-12
# 6   https://www.vie-publique.fr/discours/292385-co...  2023-12-12
# 7   https://www.vie-publique.fr/discours/292392-la...  2023-12-12
# 8   https://www.vie-publique.fr/discours/292387-co...  2023-12-12
# 9   https://www.vie-publique.fr/discours/292360-ge...  2023-12-11
# 10  https://www.vie-publique.fr/discours/292401-ca...  2023-12-11
# 11  https://www.vie-publique.fr/discours/292363-ma...  2023-12-11
#          nature                                              titre  \
# 0    Communiqué  Conseil des ministres du 12 décembre 2023. Acc...
# 1     Interview  Interview de M. Gérald Darmanin, ministre de l...
# 2   Déclaration  Déclaration de Mme Catherine Colonna, ministre...
# 3    Communiqué  Communiqué de presse du ministère de l'Europe ...
# 4    Communiqué  Conseil des ministres du 12 décembre 2023. Ter...
# 5    Communiqué  Conseil des ministres du 12 décembre 2023. Int...
# 6    Communiqué  Conseil des ministres du 12 décembre 2023. Rém...
# 7   Déclaration  Déclaration de Mme Laurence Boone, secrétaire ...
# 8    Communiqué  Conseil des ministres du 12 décembre 2023. Mes...
# 9     Interview  Interview de M. Gérald Darmanin, ministre de l...
# 10  Déclaration  Déclaration à la presse de Mme Catherine Colon...
# 11  Déclaration  Déclaration de M. Marc Fesneau, ministre de l'...
#
#                                                  lien        date
# 0   https://www.vie-publique.fr/discours/292384-co...  2023-12-12
# 1   https://www.vie-publique.fr/discours/292393-ge...  2023-12-12
# 2   https://www.vie-publique.fr/discours/292402-ca...  2023-12-12
# 3   https://www.vie-publique.fr/discours/292399-mi...  2023-12-12
# 4   https://www.vie-publique.fr/discours/292386-co...  2023-12-12
# 5   https://www.vie-publique.fr/discours/292383-co...  2023-12-12
# 6   https://www.vie-publique.fr/discours/292385-co...  2023-12-12
# 7   https://www.vie-publique.fr/discours/292392-la...  2023-12-12
# 8   https://www.vie-publique.fr/discours/292387-co...  2023-12-12
# 9   https://www.vie-publique.fr/discours/292360-ge...  2023-12-11
# 10  https://www.vie-publique.fr/discours/292401-ca...  2023-12-11
# 11  https://www.vie-publique.fr/discours/292363-ma...  2023-12-11

# %%
#show first "lien" of df
print(df['lien'][0])
# Out:
# https://www.vie-publique.fr/discours/292384-conseil-des-ministres-12122023-renovation-de-l-habitat-degrade

# %%
import pandas as pd
import os
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import dateparser
import unidecode

def find_element_text_or_nan(element, selector):
    """ Try to find and return the text of an element, or NaN if not found. """
    try:
        return element.find_element(By.CSS_SELECTOR, selector).text
    except NoSuchElementException:
        return np.nan

# Configuration du pilote Chrome
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

data_folder = "data"
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

for page_num in range(0, 2):  # Modifier ici pour plus de pages
    url = f"https://www.vie-publique.fr/discours?page={page_num}"
    driver.get(url)

    # Enregistrer le contenu HTML de la page de liste
    html_folder = os.path.join(data_folder, "html_page")
    if not os.path.exists(html_folder):
        os.makedirs(html_folder)
    html_filename = os.path.join(html_folder, f"html_page_{page_num}.html")
    with open(html_filename, "w", encoding="utf-8") as file:
        file.write(driver.page_source)  

    # Trouver tous les éléments de la classe 'fr-card__content'
    cards = driver.find_elements(By.CLASS_NAME, "fr-card__content")

    # Liste pour stocker les données initiales
    data = []

    for card in cards:
        # Using the function to find text or return NaN
        nature = find_element_text_or_nan(card, ".fr-card__start .field__item")
        title = find_element_text_or_nan(card, ".fr-card__title a")
        url = find_element_text_or_nan(card, ".fr-card__title a")

        # Parsing date separately as it involves additional logic
        date_text = find_element_text_or_nan(card, ".fr-card__end time")
        date = dateparser.parse(date_text).strftime("%d/%m/%Y") if dateparser.parse(date_text) else np.nan

        data.append({"nature": nature, "title": title, "url": url, "date": date})

    # Créer un DataFrame
    df = pd.DataFrame(data)

    # Parcourir chaque lien pour extraire des informations supplémentaires
    # Continuer après avoir extrait 'speakers'
    for index, row in df.iterrows():
        driver.get(row["url"])

        # Extraction de 'tag'
        try:
            tag = driver.find_element(By.CLASS_NAME, "vp-item-tag").text
        except NoSuchElementException:
            tag = "NA"
        df.at[index, 'tag'] = tag

        # Extraction de 'speaker'
        try:
            speakers_elements = driver.find_elements(By.CSS_SELECTOR, ".line-intervenant li")
            speakers = []
            for speaker_element in speakers_elements:
                # Extraire le texte de chaque lien (a) et le texte après le lien
                speaker_name = speaker_element.find_element(By.CSS_SELECTOR, "a").text.strip()
                speaker_title = speaker_element.text.split(" - ")[-1].split(";")[0].strip()
                speakers.append(f"{speaker_name} - {speaker_title}")
            df.at[index, 'speaker'] = " ; ".join(speakers)
        except NoSuchElementException:
            df.at[index, 'speaker'] = "NA"

        # Vérifier si 'vp-intervenant' existe et récupérer sa position
        try:
            intervenant_element = driver.find_element(By.CLASS_NAME, "vp-intervenant")
            intervenant_position = intervenant_element.location['y']
        except NoSuchElementException:
            intervenant_position = None

        # Trouver la dernière balise <p> après 'vp-intervenant'
        try:
            all_p_elements = driver.find_elements(By.CSS_SELECTOR, ".vp-discours-details p")
            for p_element in reversed(all_p_elements):
                if intervenant_position and p_element.location['y'] > intervenant_position:
                    last_p_text = p_element.text
                    break
            else:
                raise NoSuchElementException  # Aucun <p> trouvé après 'vp-intervenant'

            colonne_nom = unidecode.unidecode(last_p_text.split(":")[0].strip().split()[0].lower())
            colonne_valeur = last_p_text.split(":")[1].strip() if ":" in last_p_text else "NA"
            df.at[index, colonne_nom] = colonne_valeur
        except (NoSuchElementException, IndexError):
            pass  # Ne pas créer de colonne si l'élément est absent ou s'il y a une erreur

        # Extraction de 'text'
        try:
            text = driver.find_element(By.CLASS_NAME, "field--name-field-texte-integral").text
        except NoSuchElementException:
            text = "NA"
        df.at[index, 'text'] = text

        # Extraction de 'keywords'
        try:
            keywords_elements = driver.find_elements(By.CLASS_NAME, "fr-tag--green-emeraude")
            keywords = " ; ".join([keyword.text for keyword in keywords_elements])
        except NoSuchElementException:
            keywords = "NA"
        df.at[index, 'keywords'] = keywords

    # Sauvegarder le DataFrame en CSV dans le sous-dossier 'data/csv_page'
    csv_folder = os.path.join(data_folder, "csv_page")
    if not os.path.exists(csv_folder):
        os.makedirs(csv_folder)
    csv_filename = os.path.join(csv_folder, f"csv_page_{page_num}.csv")
    df.to_csv(csv_filename, index=False)

# Fermer le navigateur
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# c:\Users\Lucile\Documents\GitHub\public_discourse\scrapping_python.ipynb Cell 4 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=59'>60</a> # Parcourir chaque lien pour extraire des informations supplémentaires
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=60'>61</a> # Continuer après avoir extrait 'speakers'
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=61'>62</a> for index, row in df.iterrows():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=62'>63</a>     driver.get(row["url"])
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=64'>65</a>     # Extraction de 'tag'
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W3sZmlsZQ%3D%3D?line=65'>66</a>     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: chrome=120.0.6099.72)
# Stacktrace:
# 	GetHandleVerifier [0x01426E73+174291]
# 	(No symbol) [0x01350AC1]
# 	(No symbol) [0x01066E8A]
# 	(No symbol) [0x0105A152]
# 	(No symbol) [0x01058983]
# 	(No symbol) [0x01058DD8]
# 	(No symbol) [0x01068EB7]
# 	(No symbol) [0x010CA9D2]
# 	(No symbol) [0x010B700C]
# 	(No symbol) [0x010CA104]
# 	(No symbol) [0x010B6DA6]
# 	(No symbol) [0x01091034]
# 	(No symbol) [0x01091F8D]
# 	GetHandleVerifier [0x014C49CC+820268]
# 	sqlite3_dbdata_init [0x01584EBE+652494]
# 	sqlite3_dbdata_init [0x015848D9+650985]
# 	sqlite3_dbdata_init [0x0157962C+605244]
# 	sqlite3_dbdata_init [0x0158586B+654971]
# 	(No symbol) [0x0135FEBC]
# 	(No symbol) [0x01358428]
# 	(No symbol) [0x0135854D]
# 	(No symbol) [0x01345858]
# 	BaseThreadInitThunk [0x76857BA9+25]
# 	RtlInitializeExceptionChain [0x7774BD2B+107]
# 	RtlClearBits [0x7774BCAF+191]

# %%
df
# Out:
#          nature                                              titre  \
# 0   Déclaration  Déclaration à la presse de Mme Catherine Colon...
# 1   Déclaration  Déclaration de Mme Catherine Colonna, ministre...
# 2   Déclaration  Déclaration de M. Emmanuel Macron, président d...
# 3     Interview  Entretien de M. Olivier Becht, ministre délégu...
# 4    Communiqué  Communiqué de la Présidence de la République, ...
# 5   Déclaration  Déclaration de M. Bruno Le Maire, ministre de ...
# 6    Communiqué  Communiqué de la Présidence de la République, ...
# 7   Déclaration  Déclaration de Mme Élisabeth Borne, Première m...
# 8     Interview  Interview de Mme Agnès Pannier-Runacher, minis...
# 9     Interview  Extrait d'une interview de M. Jean-Noël Barrot...
# 10    Interview  Interview de Mme Élisabeth Borne, Première min...
# 11    Interview  Interview de M. Gérald Darmanin, ministre de l...
#
#                                                  lien        date  \
# 0   https://www.vie-publique.fr/discours/292401-ca...  11/12/2023
# 1   https://www.vie-publique.fr/discours/292400-ca...  10/12/2023
# 2   https://www.vie-publique.fr/discours/292372-em...  10/12/2023
# 9   Société ; Sciences - Numérique - I. A. ; Econo...    L'Etudiant
# 10  Société ; Environnement ; Eau ; Mayotte ; Séch...   France Info
# 11  Société ; Société - Population ; Politique de ...   France Info

# %%
df[10:20]
# Out:
#        nature                                              titre  \
# 10  Interview  Interview de Mme Élisabeth Borne, Première min...
# 11  Interview  Interview de M. Gérald Darmanin, ministre de l...
#
#                                                  lien        date      tag  \
# 10  https://www.vie-publique.fr/discours/292274-el...  08/12/2023  Société
# 11  https://www.vie-publique.fr/discours/292359-ge...  08/12/2023  Société
#
#                                               speaker circonstance  \
# 10                  Élisabeth Borne Première ministre          NaN
# 11  Gérald Darmanin Ministre de l'intérieur et des...          NaN
#
#                                                  text  \
# 10  FANNY CONQUY\nEt tout de suite, on écoute Élis...
# 11  JEAN-REMI BAUDOT\nBonjour Gérald DARMANIN.\nGE...
#
#                                              keywords        media
# 10  Société ; Environnement ; Eau ; Mayotte ; Séch...  France Info
# 11  Société ; Société - Population ; Politique de ...  France Info

# %%
import pandas as pd
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import dateparser
import unidecode
import time
import random

# Chrome driver configuration
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

def find_element_text_or_nan(element, selector):
    """ Try to find and return the text of an element, or NaN if not found. """
    try:
        return element.find_element(By.CSS_SELECTOR, selector).text
    except NoSuchElementException:
        return np.nan

data_folder = "data"
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Loop through pages (insert numbers)
for page_num in range(4, 12347):
    url = f"https://www.vie-publique.fr/discours?page={page_num}"
    driver.get(url)

    # Save HTML content of the list page
    html_folder = os.path.join(data_folder, "html_page")
    if not os.path.exists(html_folder):
        os.makedirs(html_folder)
    html_filename = os.path.join(html_folder, f"html_page_{page_num}.html")
    with open(html_filename, "w", encoding="utf-8") as file:
        file.write(driver.page_source)

    # Find all elements with the class 'fr-card__content'
    cards = driver.find_elements(By.CLASS_NAME, "fr-card__content")

    # List to store initial data
    data = []

    for card in cards:
        # Using the function to find text or return NaN
        nature = find_element_text_or_nan(card, ".fr-card__start .field__item")
        title = find_element_text_or_nan(card, ".fr-card__title a")
        url = find_element_text_or_nan(card, ".fr-card__title a")

        # Parsing date separately as it involves additional logic
        date_text = find_element_text_or_nan(card, ".fr-card__end time")
        date = dateparser.parse(date_text).strftime("%d/%m/%Y") if dateparser.parse(date_text) else np.nan

        data.append({"nature": nature, "title": title, "url": url, "date": date})

    # Create a DataFrame
    df = pd.DataFrame(data)

    # Loop through each link to extract additional information
    for index, row in df.iterrows():
        driver.get(row["url"])

        # Sleep for a random duration between 1 and 5 seconds (let's hope I don't get banned=>toolongdontcare)
        #time.sleep(random.uniform(1, 2))

        # Save HTML content of the current link page
        link_html_folder = os.path.join(data_folder, "url_html_page")
        if not os.path.exists(link_html_folder):
            os.makedirs(link_html_folder)
        link_html_filename = os.path.join(link_html_folder, f"html_page_{page_num}_url_{index}.html")
        with open(link_html_filename, "w", encoding="utf-8") as file:
            file.write(driver.page_source)

        # Extract 'tag'
        try:
            tag = driver.find_element(By.CLASS_NAME, "vp-item-tag").text
        except NoSuchElementException:
            tag = "NA"
        df.at[index, 'tag'] = tag

        # Extract 'speaker'
        try:
            speakers_elements = driver.find_elements(By.CSS_SELECTOR, ".line-intervenant li")
            speakers = []
            for speaker_element in speakers_elements:
                speaker_name = speaker_element.find_element(By.CSS_SELECTOR, "a").text.strip()
                speaker_title = speaker_element.text.split(" - ")[-1].split(";")[0].strip()
                speakers.append(f"{speaker_name} - {speaker_title}")
            df.at[index, 'speaker'] = " ; ".join(speakers)
        except NoSuchElementException:
            df.at[index, 'speaker'] = "NA"

        # Check if 'vp-intervenant' exists and get its position
        try:
            intervenant_element = driver.find_element(By.CLASS_NAME, "vp-intervenant")
            intervenant_position = intervenant_element.location['y']
        except NoSuchElementException:
            intervenant_position = None

        # Find the last <p> tag after 'vp-intervenant'
        try:
            all_p_elements = driver.find_elements(By.CSS_SELECTOR, ".vp-discours-details p")
            for p_element in reversed(all_p_elements):
                if intervenant_position and p_element.location['y'] > intervenant_position:
                    last_p_text = p_element.text
                    break
            else:
                raise NoSuchElementException  # No <p> found after 'vp-intervenant'

            column_name = unidecode.unidecode(last_p_text.split(":")[0].strip().split()[0].lower()) # Remove accents + lower case
            column_value = last_p_text.split(":")[1].strip() if ":" in last_p_text else "NA"
            df.at[index, column_name] = column_value
        except (NoSuchElementException, IndexError):
            pass  # Do not create column if the element is absent or there is an error

        # Extract 'text'
        try:
            text = driver.find_element(By.CLASS_NAME, "field--name-field-texte-integral").text
        except NoSuchElementException:
            text = "NA"
        df.at[index, 'text'] = text

        # Extract 'keywords'
        try:
            keywords_elements = driver.find_elements(By.CLASS_NAME, "fr-tag--green-emeraude")
            keywords = " ; ".join([keyword.text for keyword in keywords_elements])
        except NoSuchElementException:
            keywords = "NA"
        df.at[index, 'keywords'] = keywords

    # Save the DataFrame in CSV in the 'data/csv_page' subfolder
    csv_folder = os.path.join(data_folder, "csv_page")
    if not os.path.exists(csv_folder):
        os.makedirs(csv_folder)
    csv_filename = os.path.join(csv_folder, f"csv_page_{page_num}.csv")
    df.to_csv(csv_filename, index=False)

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\Lucile\Documents\GitHub\public_discourse\scrapping_python.ipynb Cell 7 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W6sZmlsZQ%3D%3D?line=41'>42</a> title = card.find_element(By.CSS_SELECTOR, ".fr-card__title a").text
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W6sZmlsZQ%3D%3D?line=42'>43</a> url = card.find_element(By.CSS_SELECTOR, ".fr-card__title a").get_attribute("href")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W6sZmlsZQ%3D%3D?line=43'>44</a> date_text = card.find_element(By.CSS_SELECTOR, ".fr-card__end time").text
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W6sZmlsZQ%3D%3D?line=44'>45</a> date = dateparser.parse(date_text).strftime("%d/%m/%Y") if dateparser.parse(date_text) else None
#      <a href='vscode-notebook-cell:/c%3A/Users/Lucile/Documents/GitHub/public_discourse/scrapping_python.ipynb#W6sZmlsZQ%3D%3D?line=46'>47</a> data.append({"nature": nature, "title": title, "url": url, "date": date})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:425, in WebElement.find_element(self, by, value)
#     422     by = By.CSS_SELECTOR
#     423     value = f'[name="{value}"]'
# --> 425 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".fr-card__end time"}
#   (Session info: chrome=120.0.6099.72)
# Stacktrace:
# 	GetHandleVerifier [0x01426E73+174291]
# 	(No symbol) [0x01350AC1]
# 	(No symbol) [0x01066FF6]
# 	(No symbol) [0x01099876]
# 	(No symbol) [0x01099C2C]
# 	(No symbol) [0x01092631]
# 	(No symbol) [0x010B7054]
# 	(No symbol) [0x010925B0]
# 	(No symbol) [0x010B7414]
# 	(No symbol) [0x010CA104]
# 	(No symbol) [0x010B6DA6]
# 	(No symbol) [0x01091034]
# 	(No symbol) [0x01091F8D]
# 	GetHandleVerifier [0x014C49CC+820268]
# 	sqlite3_dbdata_init [0x01584EBE+652494]
# 	sqlite3_dbdata_init [0x015848D9+650985]
# 	sqlite3_dbdata_init [0x0157962C+605244]
# 	sqlite3_dbdata_init [0x0158586B+654971]
# 	(No symbol) [0x0135FEBC]
# 	(No symbol) [0x01358428]
# 	(No symbol) [0x0135854D]
# 	(No symbol) [0x01345858]
# 	BaseThreadInitThunk [0x76857BA9+25]
# 	RtlInitializeExceptionChain [0x7774BD2B+107]
# 	RtlClearBits [0x7774BCAF+191]

# %%
df
# Out:
#          nature                                              title  \
# 0   Déclaration  Déclaration à la presse de Mme Catherine Colon...
# 1   Déclaration  Déclaration de Mme Catherine Colonna, ministre...
# 2   Déclaration  Déclaration de M. Emmanuel Macron, président d...
# 3     Interview  Entretien de M. Olivier Becht, ministre délégu...
# 4    Communiqué  Communiqué de la Présidence de la République, ...
# 5   Déclaration  Déclaration de M. Bruno Le Maire, ministre de ...
# 6    Communiqué  Communiqué de la Présidence de la République, ...
# 7   Déclaration  Déclaration de Mme Élisabeth Borne, Première m...
# 8     Interview  Interview de Mme Agnès Pannier-Runacher, minis...
# 9     Interview  Extrait d'une interview de M. Jean-Noël Barrot...
# 10    Interview  Interview de Mme Élisabeth Borne, Première min...
# 11    Interview  Interview de M. Gérald Darmanin, ministre de l...
#
#                                                   url        date  \
# 0   https://www.vie-publique.fr/discours/292401-ca...  11/12/2023
# 1   https://www.vie-publique.fr/discours/292400-ca...  10/12/2023
# 2   https://www.vie-publique.fr/discours/292372-em...  10/12/2023
# 3   https://www.vie-publique.fr/discours/292394-en...  08/12/2023
# 4   https://www.vie-publique.fr/discours/292297-pr...  08/12/2023
# 5   https://www.vie-publique.fr/discours/292365-br...  08/12/2023
# 6   https://www.vie-publique.fr/discours/292366-pr...  08/12/2023
